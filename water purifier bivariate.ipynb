# %% [markdown]
# # 2 . Bi-variate   Analysis

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import requests 
from bs4 import BeautifulSoup

import re

# %%
df4=pd.read_csv(r"C:\Users\user\Downloads\Water_purifier3.csv") 
df4
# Out:
#                  ProductName  Price(₹)  Original_cost(₹)  Rating  Discount(%)  \
# 0                 Pureit Max     13999             22500     4.4         37.0
# 1                 Aqua Fresh      4199             16500     4.0         74.0
# 2                    MarQ by      3999             16500     4.0         75.0
# 3                Kinsco Aqua      4299             20000     4.1         78.0
# 4                   KENT Ace     13999             19500     4.4         28.0
# ..                       ...       ...               ...     ...          ...
# 402             Keel Mineral      3983             16500     3.2         75.0
# 403  Aquaguard RO+UV+UF+MTDS     14800             21990     3.3         32.0
# 404           AquaActive Hot     11768             34000     4.3         65.0
# 405                AQUA DOVE      4769             12500     4.3         61.0
# 406          Royal Aquafresh      3599             16500     4.7         78.0
#
#     Delivery_offers           Type_models            ProductName.1  \
# 0     Free delivery  Electrical & Storage               Pureit Max
# 1     Free delivery  Electrical & Storage               Aqua Fresh
# 2     Free delivery  Electrical & Storage                  MarQ by
# 3     Free delivery  Electrical & Storage              Kinsco Aqua
# 4     Free delivery  Electrical & Storage                 KENT Ace
# ..              ...                   ...                      ...
# 402   Free delivery  Electrical & Storage             Keel Mineral
# 403   Free delivery  Electrical & Storage  Aquaguard RO+UV+UF+MTDS
# 404   Free delivery  Electrical & Storage           AquaActive Hot
# 405   Free delivery  Electrical & Storage                AQUA DOVE
# 406   Free delivery  Electrical & Storage          Royal Aquafresh
#
#      Capacity (L/hr)
# 0                 24
# 1                 12
# 2                 12
# 3                 15
# 4                  5
# ..               ...
# 402               20
# 403                5
# 404               12
# 405               12
# 406                8
#
# [407 rows x 9 columns]

# %%
##df4.drop(columns='Unnamed: 0',inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df4
# Out:
#                  ProductName  Price(₹)  Original_cost(₹)  Rating  Discount(%)  \
# 0                 Pureit Max     13999             22500     4.4         37.0
# 1                 Aqua Fresh      4199             16500     4.0         74.0
# 2                    MarQ by      3999             16500     4.0         75.0
# 3                Kinsco Aqua      4299             20000     4.1         78.0
# 4                   KENT Ace     13999             19500     4.4         28.0
# ..                       ...       ...               ...     ...          ...
# 402             Keel Mineral      3983             16500     3.2         75.0
# 403  Aquaguard RO+UV+UF+MTDS     14800             21990     3.3         32.0
# 404           AquaActive Hot     11768             34000     4.3         65.0
# 405                AQUA DOVE      4769             12500     4.3         61.0
# 406          Royal Aquafresh      3599             16500     4.7         78.0
#
#     Delivery_offers           Type_models            ProductName.1  \
# 0     Free delivery  Electrical & Storage               Pureit Max
# 1     Free delivery  Electrical & Storage               Aqua Fresh
# 2     Free delivery  Electrical & Storage                  MarQ by
# 3     Free delivery  Electrical & Storage              Kinsco Aqua
# 4     Free delivery  Electrical & Storage                 KENT Ace
# ..              ...                   ...                      ...
# 402   Free delivery  Electrical & Storage             Keel Mineral
# 403   Free delivery  Electrical & Storage  Aquaguard RO+UV+UF+MTDS
# 404   Free delivery  Electrical & Storage           AquaActive Hot
# 405   Free delivery  Electrical & Storage                AQUA DOVE
# 406   Free delivery  Electrical & Storage          Royal Aquafresh
#
#      Capacity (L/hr)
# 0                 24
# 1                 12
# 2                 12
# 3                 15
# 4                  5
# ..               ...
# 402               20
# 403                5
# 404               12
# 405               12
# 406                8
#
# [407 rows x 9 columns]

# %%
df=df4.corr()
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11852\2065119356.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df4.corr()
#                   Price(₹)  Original_cost(₹)    Rating  Discount(%)  \
# Price(₹)          1.000000          0.542844  0.293952    -0.550020
# Original_cost(₹)  0.542844          1.000000  0.198525    -0.038185
# Rating            0.293952          0.198525  1.000000    -0.248243
# Discount(%)      -0.550020         -0.038185 -0.248243     1.000000
# Capacity (L/hr)   0.008640          0.030857 -0.048279     0.048550
#
#                   Capacity (L/hr)
# Price(₹)                 0.008640
# Original_cost(₹)         0.030857
# Rating                  -0.048279
# Discount(%)              0.048550
# Capacity (L/hr)          1.000000

# %%
df4[df4['Price(₹)']>80000]
# Out:
#     ProductName  Price(₹)  Original_cost(₹)  Rating  Discount(%)  \
# 334    Bio Plus     90000             16599     4.3         43.5
#
#     Delivery_offers                 Type_models ProductName.1  Capacity (L/hr)
# 334   Free delivery  Electrical & Non - Storage      Bio Plus               90

# %%
#df4=df4.drop([0,1,2],axis=0)

# %% [markdown]
# # Scatter plot
#
# ### Numerical vs Numerical

# %%
#plt.figure(figsize=[60,60])
##sns.scatterplot(df4["Price(₹)"],df4["Discount(%)"])

# %%
plt.figure(figsize=(15,6))
plt.scatter(df4["Price(₹)"],df4["Original_cost(₹)"])

# %% [markdown]
# # Observations
# - Price between 0-30,000Rs/- having more items
# - Original price between 0-40,000Rs/- having more items

# %%
plt.scatter(df4["Price(₹)"],df4["Discount(%)"])

# %% [markdown]
# # Observations
# - Price between 0-25,000Rs/- under discount between 0-80% having more items

# %% [markdown]
# # pair plot

# %% [markdown]
# ### Numerical vs Numerical

# %%
sns.pairplot(df4)

# %% [markdown]
# ## line plot
# ### Categorical vs Numerical

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=df4, x="Type_models", y="Discount(%)")
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Electrical & Storage'),
#   Text(1, 0, 'Non - Electrical & Storage'),
#   Text(2, 0, 'Electrical & Non - Storage'),
#   Text(3, 0, 'Non - Electrical & Non - Storage')])

# %% [markdown]
# # Observations
# - Non-Electrical & Non-Storage purifiers having discount between 45-60%
# - Electrical & Storage purifiers having discount between 52-54%

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=df4, x="Type_models", y="Capacity (L/hr)")
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Electrical & Storage'),
#   Text(1, 0, 'Non - Electrical & Storage'),
#   Text(2, 0, 'Electrical & Non - Storage'),
#   Text(3, 0, 'Non - Electrical & Non - Storage')])

# %% [markdown]
# # Observations
# - Electrical & Non-Storage purifiers having capacity more then 200(L/hr)
# - Non-Electrical & Storage purifiers having less capacity upto 10(L/hr)

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=df4, x="Type_models", y="Price(₹)")
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Electrical & Storage'),
#   Text(1, 0, 'Non - Electrical & Storage'),
#   Text(2, 0, 'Electrical & Non - Storage'),
#   Text(3, 0, 'Non - Electrical & Non - Storage')])

# %% [markdown]
# ### Numerical vs Numerical

# %%
z=df4[df4['Price(₹)']<3000000 ]

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Rating',y='Price(₹)',data=pd.DataFrame(z))
# Most preferred rating is 4.5 with price 12500 to 15000
# Out:
# <Axes: xlabel='Rating', ylabel='Price(₹)'>

# %% [markdown]
# ## Boxplot

# %% [markdown]
# ### Numerical vs Numerical

# %%
df4.head()
# Out:
#    ProductName  Price(₹)  Original_cost(₹)  Rating  Discount(%)  \
# 0   Pureit Max     13999             22500     4.4         37.0
# 1   Aqua Fresh      4199             16500     4.0         74.0
# 2      MarQ by      3999             16500     4.0         75.0
# 3  Kinsco Aqua      4299             20000     4.1         78.0
# 4     KENT Ace     13999             19500     4.4         28.0
#
#   Delivery_offers           Type_models ProductName.1  Capacity (L/hr)
# 0   Free delivery  Electrical & Storage    Pureit Max               24
# 1   Free delivery  Electrical & Storage    Aqua Fresh               12
# 2   Free delivery  Electrical & Storage       MarQ by               12
# 3   Free delivery  Electrical & Storage   Kinsco Aqua               15
# 4   Free delivery  Electrical & Storage      KENT Ace                5

# %%
plt.figure(figsize=[15,10])
sns.boxplot(x="Rating", y="Price(₹)", data=df4)
plt.title('rating of price')
plt.ylim(0,50000)
#plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # observation
# + The least rating at 1.0 have more ratings in the price between 5000-25000/-Rs

# %%
plt.figure(figsize=[20,8])
sns.boxplot(x="Type_models", y="Price(₹)", data=df4)
plt.ylim(0,30000)
# Out:
# (0.0, 30000.0)

# %% [markdown]
# # Observations
# - Electrical & stroarge purifiers and Electrical & Non-storage purifiers having more price range between 5,000-12,000/-Rs and 5,000-10,000/-Rs.
# - Non-Electrical & storage purifiers and Non-electrical & Non-Storage purifiers have lowest prices from 2,000-4,000 and 1,000-2,000/-Rs.

# %% [markdown]
# # Heat Map

# %% [markdown]
# ### Numerical vs Numerical

# %%
plt.figure(figsize=(10,6)) # very useful plot to check correlations between any two numerical variables
sns.heatmap(df4.corr(),annot=True)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11852\1271216165.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df4.corr(),annot=True)

# %%
df=df4.corr()
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11852\2065119356.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df4.corr()
#                   Price(₹)  Original_cost(₹)    Rating  Discount(%)  \
# Price(₹)          1.000000          0.542844  0.293952    -0.550020
# Original_cost(₹)  0.542844          1.000000  0.198525    -0.038185
# Rating            0.293952          0.198525  1.000000    -0.248243
# Discount(%)      -0.550020         -0.038185 -0.248243     1.000000
# Capacity (L/hr)   0.008640          0.030857 -0.048279     0.048550
#
#                   Capacity (L/hr)
# Price(₹)                 0.008640
# Original_cost(₹)         0.030857
# Rating                  -0.048279
# Discount(%)              0.048550
# Capacity (L/hr)          1.000000

# %% [markdown]
# ## Bar Graph  -
# ### Numerical vs Categorical

# %%
plt.figure(figsize=(20,4))
product_name=["AQUA GLORY","SAMTA 14","Royal Aquafresh","Blue Star","Grand plus","Aqua Fresh"]
Rating_in_k=[1,2,3,4,5,6]
plt.bar(product_name,Rating_in_k,color='blue',edgecolor='red') # bar is vertical, barh gives horizontal bar
plt.title("Product and Rating",fontsize=20)
plt.xlabel('Productname')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# # Observations
# - Aqua Fresh purifier having highest rating upto 6.
# - Aqua Glory purifier having lowest rating upto 1.

# %%
#c=df4[df4['Price(₹)']<600000]

# %%
#plt.figure(figsize=(20,10))
#sns.barplot(y='ProductName',x='Price(₹)',data=pd.DataFrame(c))
#sns.set_context('paper',font_scale=3)

# %% [markdown]
# # Observations
# - Peore Pro having more price upto 13,800.Rs
# - Royal Aquafresh and Aqua Dove having least price upto 4,000.Rs

# %% [markdown]
# # Violin plot

# %% [markdown]
# ### Categorical vs numerical

# %%
sns.violinplot(data=df4,x="Type_models",y="Discount(%)")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Observations
# - Electrical & storage items have more discount between 60%-80% and Non-Electrical & Storage items have more discount at 5%-20%
# - Electrical & Non-Stroage items have more discount between 60%-80% and Non-Electrical & Non-Storage items have discount at 60%-80%
