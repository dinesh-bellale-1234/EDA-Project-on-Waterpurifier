# %% [markdown]
# # 3 . Multi-Variate Analysis

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import requests
from bs4 import BeautifulSoup

import re

# %%
df4=pd.read_csv(r"C:\Users\user\Downloads\Water_purifier3.csv") 
df4
# Out:
#                  ProductName  Price(₹)  Original_cost(₹)  Rating  Discount(%)  \
# 0                 Pureit Max     13999             22500     4.4         37.0
# 1                 Aqua Fresh      4199             16500     4.0         74.0
# 2                    MarQ by      3999             16500     4.0         75.0
# 3                Kinsco Aqua      4299             20000     4.1         78.0
# 4                   KENT Ace     13999             19500     4.4         28.0
# ..                       ...       ...               ...     ...          ...
# 402             Keel Mineral      3983             16500     3.2         75.0
# 403  Aquaguard RO+UV+UF+MTDS     14800             21990     3.3         32.0
# 404           AquaActive Hot     11768             34000     4.3         65.0
# 405                AQUA DOVE      4769             12500     4.3         61.0
# 406          Royal Aquafresh      3599             16500     4.7         78.0
#
#     Delivery_offers           Type_models            ProductName.1  \
# 0     Free delivery  Electrical & Storage               Pureit Max
# 1     Free delivery  Electrical & Storage               Aqua Fresh
# 2     Free delivery  Electrical & Storage                  MarQ by
# 3     Free delivery  Electrical & Storage              Kinsco Aqua
# 4     Free delivery  Electrical & Storage                 KENT Ace
# ..              ...                   ...                      ...
# 402   Free delivery  Electrical & Storage             Keel Mineral
# 403   Free delivery  Electrical & Storage  Aquaguard RO+UV+UF+MTDS
# 404   Free delivery  Electrical & Storage           AquaActive Hot
# 405   Free delivery  Electrical & Storage                AQUA DOVE
# 406   Free delivery  Electrical & Storage          Royal Aquafresh
#
#      Capacity (L/hr)
# 0                 24
# 1                 12
# 2                 12
# 3                 15
# 4                  5
# ..               ...
# 402               20
# 403                5
# 404               12
# 405               12
# 406                8
#
# [407 rows x 9 columns]

# %%
 df4.describe()
# Out:
#            Price(₹)  Original_cost(₹)      Rating  Discount(%)  \
# count    407.000000        407.000000  407.000000   407.000000
# mean    8359.545455      16447.793612    4.091155    52.093366
# std     7578.188332       7449.336929    0.386433    22.317732
# min      279.000000        399.000000    2.000000     3.000000
# 25%     3999.000000      13500.000000    3.900000    34.000000
# 50%     5074.000000      16500.000000    4.200000    60.000000
# 75%    11666.500000      19999.000000    4.300000    72.000000
# max    90000.000000      56899.000000    5.000000    82.000000
#
#        Capacity (L/hr)
# count       407.000000
# mean        121.368550
# std         899.051337
# min           1.000000
# 25%           5.000000
# 50%          12.000000
# 75%          15.000000
# max       10000.000000

# %%
df4.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Box plot :

# %%
plt.figure(figsize=[20,8])
sns.boxplot(data=df4, x="Type_models", y="Price(₹)", hue="Delivery_offers")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Observations
# - Ao Smith has more price in the range of above 30000
# - Aqua dove has less price in the range of below 1000

# %%
plt.figure(figsize=[20,8])
sns.boxplot(data=df4, x="Type_models", y="Discount(%)", hue="Delivery_offers")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Observations
# - Electrical & Storage purifiers and Electrical & Non-storage purifiers have more discount offers
# - Non-Electrical & Storage purifiers and Non-Electrical & Non-Storage purifiers have less discount offers.

# %% [markdown]
# # violin plot

# %%
sns.violinplot(data=df4,x="Type_models",y="Discount(%)")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Observations
# - Electrical & Storage purifiers having free delivery at discount range of 65%-70%
# - Non-Electricl & Storage purifiers having delivery charges at discount range 5%-30%
# - Electrical & Non-storage purifiers having delivery charges at disccount range 20%-60%

# %%
plt.figure(figsize=[10,5])
sns.boxplot(data=df4, x="Type_models", y="Rating", hue="Delivery_offers")
#plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Observations
# - Electrical & Storage purifiers for free delivery items have more ratings above 4.0
# - Non-electrical & Storage purifiers having less ratings below 4.0
